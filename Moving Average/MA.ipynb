# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
df = yf.Ticker("SMT.L").history(period="max")

# %%
plt.plot(df['Close'])

# %%
df['MA'] = df['Close'].rolling(50).mean()
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1968-12-31 00:00:00+01:00     4.802247     4.802247     4.802247     4.802247
# 1969-01-01 00:00:00+01:00     4.802247     4.802247     4.802247     4.802247
# 1969-01-02 00:00:00+01:00     4.802247     4.802247     4.802247     4.802247
# 1969-01-03 00:00:00+01:00     4.802247     4.802247     4.802247     4.802247
# 1969-01-06 00:00:00+01:00     4.802247     4.802247     4.802247     4.802247
# ...                                ...          ...          ...          ...
# 2026-01-26 00:00:00+00:00  1207.500000  1210.000000  1196.000000  1202.000000
# 2026-01-27 00:00:00+00:00  1204.500000  1211.500000  1201.500000  1210.000000
# 2026-01-28 00:00:00+00:00  1218.000000  1239.000000  1211.000000  1235.500000
# 2026-01-29 00:00:00+00:00  1241.000000  1263.000000  1236.500000  1240.000000
# 2026-01-30 00:00:00+00:00  1250.000000  1262.000000  1243.000000  1255.500000
#
#                             Volume  Dividends  Stock Splits           MA
# Date
# 1968-12-31 00:00:00+01:00        0        0.0           0.0          NaN
# 1969-01-01 00:00:00+01:00        0        0.0           0.0          NaN
# 1969-01-02 00:00:00+01:00        0        0.0           0.0          NaN
# 1969-01-03 00:00:00+01:00        0        0.0           0.0          NaN
# 1969-01-06 00:00:00+01:00        0        0.0           0.0          NaN
# ...                            ...        ...           ...          ...
# 2026-01-26 00:00:00+00:00  1558929        0.0           0.0  1141.038372
# 2026-01-27 00:00:00+00:00  1395721        0.0           0.0  1143.278704
# 2026-01-28 00:00:00+00:00  2159765        0.0           0.0  1146.199033
# 2026-01-29 00:00:00+00:00  2513838        0.0           0.0  1149.359360
# 2026-01-30 00:00:00+00:00  1378004        0.0           0.0  1153.369680
#
# [14728 rows x 8 columns]

# %%
TICKER = 'SMT.L'

df = yf.Ticker(TICKER).history(period="max")
df['MA'] = df['Close'].rolling(50).mean()

df = df.iloc[-100:, :] #last 100 row, all columns

plt.plot(df['Close']) 
plt.plot(df['MA'])
plt.title(f'{TICKER} Close vs. Moving Average')
# Out:
# Text(0.5, 1.0, 'SMT.L Close vs. Moving Average')
