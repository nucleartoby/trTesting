# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
df = yf.Ticker("SMT.L").history(period="max")

# %%
plt.plot(df['Close'])

# %%
df['MA'] = df['Close'].rolling(50).mean()
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1968-12-31 00:00:00+01:00     4.80232     4.80232     4.80232     4.80232
# 1969-01-01 00:00:00+01:00     4.80232     4.80232     4.80232     4.80232
# 1969-01-02 00:00:00+01:00     4.80232     4.80232     4.80232     4.80232
# 1969-01-03 00:00:00+01:00     4.80232     4.80232     4.80232     4.80232
# 1969-01-06 00:00:00+01:00     4.80232     4.80232     4.80232     4.80232
# ...                               ...         ...         ...         ...
# 2025-10-06 00:00:00+01:00  1147.00000  1150.00000  1135.00000  1135.00000
# 2025-10-07 00:00:00+01:00  1138.00000  1147.00000  1133.50000  1133.50000
# 2025-10-08 00:00:00+01:00  1138.50000  1151.00000  1135.00000  1151.00000
# 2025-10-09 00:00:00+01:00  1156.00000  1160.00000  1134.00000  1144.00000
# 2025-10-10 00:00:00+01:00  1140.50000  1153.50000  1115.50000  1122.00000
#
#                             Volume  Dividends  Stock Splits  Capital Gains  \
# Date
# 1968-12-31 00:00:00+01:00        0        0.0           0.0            0.0
# 1969-01-01 00:00:00+01:00        0        0.0           0.0            0.0
# 1969-01-02 00:00:00+01:00        0        0.0           0.0            0.0
# 1969-01-03 00:00:00+01:00        0        0.0           0.0            0.0
# 1969-01-06 00:00:00+01:00        0        0.0           0.0            0.0
# ...                            ...        ...           ...            ...
# 2025-10-06 00:00:00+01:00  2344149        0.0           0.0            0.0
# 2025-10-07 00:00:00+01:00  2083637        0.0           0.0            0.0
# 2025-10-08 00:00:00+01:00  1942256        0.0           0.0            0.0
# 2025-10-09 00:00:00+01:00  3211780        0.0           0.0            0.0
# 2025-10-10 00:00:00+01:00  2536756        0.0           0.0            0.0
#
#                                 MA
# Date
# 1968-12-31 00:00:00+01:00      NaN
# 1969-01-01 00:00:00+01:00      NaN
# 1969-01-02 00:00:00+01:00      NaN
# 1969-01-03 00:00:00+01:00      NaN
# 1969-01-06 00:00:00+01:00      NaN
# ...                            ...
# 2025-10-06 00:00:00+01:00  1101.75
# 2025-10-07 00:00:00+01:00  1102.76
# 2025-10-08 00:00:00+01:00  1104.24
# 2025-10-09 00:00:00+01:00  1105.32
# 2025-10-10 00:00:00+01:00  1105.80
#
# [14651 rows x 9 columns]

# %%
TICKER = 'SMT.L'

df = yf.Ticker(TICKER).history(period="max")
df['MA'] = df['Close'].rolling(50).mean()

df = df.iloc[-100:, :] #last 100 row, all columns

plt.plot(df['Close']) 
plt.plot(df['MA'])
plt.title(f'{TICKER} Close vs. Moving Average')
# Out:
# Text(0.5, 1.0, 'SMT.L Close vs. Moving Average')
